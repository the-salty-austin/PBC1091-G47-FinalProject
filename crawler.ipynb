# %%
import requests
import json
url = 'https://www.google.com/maps/preview/review/listentitiesreviews?authuser=0&hl=zh-TW&gl=tw&pb=!1m2!1y3765758657372873253!2y7421598300058256399!2m2!1i8!2i10!3e1!4m5!3b1!4b1!5b1!6b1!7b1!5m2!1slHTYX7v0NLKVr7wP8NGSgAU!7e81'
rt = requests.get(url).text
pretext = ')]}\''
text = rt.replace(pretext, '')

soup = json.loads(text)

conlist = soup[2]

for i in conlist:
    print('username:' + str(i[0][1]))
    print('time:' + str(i[1]))
    print('comment:' + str(i[3]))
    print('rate:' + str(i[4]))
    print('=====')
# Out:
# username:陳少愷
# time:1 個月前
# comment:各類音樂藝文表演場所，價格公道，音場還過的去
# rate:4
# =====
# username:Janis Lee
# time:4 個月前
# comment:場地是很不錯，氣氛很ok，就是空間小了一點，若要跟別人共桌也很尷尬，但整體上還算是可以推薦的地方👍
# rate:4
# =====
# username:沈才修
# time:3 個月前
# comment:座位多，看表演很輕鬆
# 可以點酒水來喝
# rate:4
# =====
# username:貳行程樂團
# time:1 年前
# comment:感謝河岸給我們機會演出，我們來自屏東，貳行程樂團
# rate:5
# =====
# username:jason sun
# time:2 個月前
# comment:中小型表演場地！溫馨小酒館！
# rate:5
# =====
# username:經武陳
# time:3 天前
# comment:休閒聽好歌，棒
# rate:4
# =====
# username:游偉哲
# time:8 個月前
# comment:空間不大，但蠻溫馨舒適的，在這裡聽歌手唱歌然後喝點小酒是件很享受的事。
# rate:5
# =====
# username:James Hung
# time:10 個月前
# comment:整體感受佳，舞台稍偏小，是個溫馨的小空間
# rate:4
# =====
# username:Nicole PENG
# time:2 個月前
# comment:燈光美！舞台氣氛很好！
# rate:4
# =====
# username:Eris Feng
# time:1 年前
# comment:店內空間不大，大約有40個座位，設備舊舊的，環境不算好，位置也安排的很緊湊，飲料和食物的CP值也不高。所以來這裡的重點還是：聽，音，樂，啦！！這裡定期都會舉辦很多現場的音樂表演活動，通常都是比較還不知名的獨立歌手，場地小小的剛好有機會可以和喜歡的樂團成員靠的很近，是一個愛音樂的人會愛的地方！（不太愛看現場表演的朋友千萬別來，畢竟這裡的飲料食物價位還是咖啡廳價位...）
# rate:4
# =====

# %%
county = input()
place = input()
url = 'https://ifoodie.tw/explore/' + county + '/list/' + place + '?page='

attr = {'class': 'jsx-2133253768 title-text'}

print(url)
# Out:
# 彰化縣
# 大村鄉
# https://ifoodie.tw/explore/彰化縣/list/大村鄉

# %%
import requests
from bs4 import BeautifulSoup

county = input('輸入縣市：')
place = input('輸入地區：')
url_ori = 'https://ifoodie.tw/explore/' + county + '/list/' + place + '?page='

attr_num = {'class': 'jsx-2606512903'}
temp_num = soup.find_all('span', attrs = attr_num)[2].get_text()

temp_num = temp_num.replace('(', '')
temp_num = temp_num.replace(')', '')
num = (int(temp_num)//15)+1

x = 0
for a in range(num):
    url = url_ori + str(a+1)
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')
    attr = {'class': 'jsx-2133253768 title-text'}
    names = soup.find_all('a', attrs = attr)
    for i in names:
        x += 1
        print(i.get_text())
        print('=====')
# Out:
# 輸入縣市：彰化縣
# 輸入地區：員林市
# 鍋泰山。南洋鍋物
# =====
# 1
# 有片森林 FOREST ROASTING
# =====
# 2
# House V 好室鍋物-員林店
# =====
# 3
# 丰富食堂 Home Foodie
# =====
# 4
# All In Coffee
# =====
# 5
# 吳家紅茶冰 員林南平店
# =====
# 6
# 建宏拉仔麵
# =====
# 7
# 芸彰牧場 台灣牛肉料理專賣店 員林店
# =====
# 8
# 貓樂町
# =====
# 9
# 楊家肉圓碗粿
# =====
# 10
# 邱記早點
# =====
# 11
# N O V .Cafe
# =====
# 12
# 哈爾濱酸菜白肉鍋
# =====
# 13
# 樂曼尼豆花冰品
# =====
# 14
# Attic小閣樓 員林店
# =====
# 15
# 每食Lagom
# =====
# 16
# 百川通食舖
# =====
# 17
# 王爺到-新式茶店
# =====
# 18
# 三年五班黑糖珍珠鋪-員林靜修店
# =====
# 19
# 諾伊nooi cafe & brunch（員林店）
# =====
# 20
# 豬對有韓式烤肉吃到飽(員林店)
# =====
# 21
# 關於餐桌 About Tables
# =====
# 22
# 員林台北小吃
# =====
# 23
# 米蘭街義式小館員林館
# =====
# 24
# 品屋牛排館
# =====
# 25
# 極光森林 Aurora Forest
# =====
# 26
# 韓家芸
# =====
# 27
# 曾家純蔗糖（興達純蔗糖-天然飲品專賣）
# =====
# 28
# 冰鎮屋
# =====
# 29
# 日日豆珈琲飲品專賣
# =====
# 30
# 琉璃仙境
# =====
# 31
# 日佐甜室
# =====
# 32
# 鰭酒藏日式料理
# =====
# 33
# 桂林四神湯
# =====
# 34
# Am田園早午餐
# =====
# 35
# 老二早點
# =====
# 36
# Zugo Cafe 圓
# =====
# 37
# 六畝良食鍋物
# =====
# 38
# 井閣 鍋物料理
# =====
# 39
# 泰之飲泰式家鄉菜
# =====
# 40
# 野島家咖哩屋 員林店
# =====
# 41
# 窩嚐咖啡自家烘焙館
# =====
# 42
# 秋瀾號 咖啡專賣所
# =====
# 43
# 所在suo zai 舒芙蕾
# =====
# 44
# 國際牛肉麵
# =====
# 45
# 原味千尋
# =====
# 46
# 光興牛肉爐
# =====
# 47
# 土木公社員林店
# =====
# 48
# 饗·料理
# =====
# 49
# O MY GOOD 歐麥谷
# =====
# 50
# 陽光麵線 員林創始總店
# =====
# 51
# 阿宏綠豆沙牛乳
# =====
# 52
# 微笑咖哩-員林店
# =====
# 53
# 出櫃冷飲-員林中山店
# =====
# 54
# KoKoMo私房惑櫃 Lounge & Tea time
# =====
# 55
# 梅干扣肉阿成
# =====
# 56
# 回鍋～冷藏/熟成/極肉專門
# =====
# 57
# 穙食雞蛋糕
# =====
# 58
# 日常與菜 每日鍋物
# =====
# 59
# 初禾-手作甜點‧咖啡-員初店
# =====
# 60
# 蘿蕬森活廚房
