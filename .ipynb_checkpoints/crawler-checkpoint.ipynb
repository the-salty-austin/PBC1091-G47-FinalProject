# %%
import requests
import json
url = 'https://www.google.com/maps/preview/review/listentitiesreviews?authuser=0&hl=zh-TW&gl=tw&pb=!1m2!1y3765758657372873253!2y7421598300058256399!2m2!1i8!2i10!3e1!4m5!3b1!4b1!5b1!6b1!7b1!5m2!1slHTYX7v0NLKVr7wP8NGSgAU!7e81'
rt = requests.get(url).text
pretext = ')]}\''
text = rt.replace(pretext, '')

soup = json.loads(text)

conlist = soup[2]

for i in conlist:
    print('username:' + str(i[0][1]))
    print('time:' + str(i[1]))
    print('comment:' + str(i[3]))
    print('rate:' + str(i[4]))
    print('=====')
# Out:
# username:陳少愷
# time:1 個月前
# comment:各類音樂藝文表演場所，價格公道，音場還過的去
# rate:4
# =====
# username:Janis Lee
# time:4 個月前
# comment:場地是很不錯，氣氛很ok，就是空間小了一點，若要跟別人共桌也很尷尬，但整體上還算是可以推薦的地方👍
# rate:4
# =====
# username:沈才修
# time:3 個月前
# comment:座位多，看表演很輕鬆
# 可以點酒水來喝
# rate:4
# =====
# username:貳行程樂團
# time:1 年前
# comment:感謝河岸給我們機會演出，我們來自屏東，貳行程樂團
# rate:5
# =====
# username:jason sun
# time:2 個月前
# comment:中小型表演場地！溫馨小酒館！
# rate:5
# =====
# username:經武陳
# time:3 天前
# comment:休閒聽好歌，棒
# rate:4
# =====
# username:游偉哲
# time:8 個月前
# comment:空間不大，但蠻溫馨舒適的，在這裡聽歌手唱歌然後喝點小酒是件很享受的事。
# rate:5
# =====
# username:James Hung
# time:10 個月前
# comment:整體感受佳，舞台稍偏小，是個溫馨的小空間
# rate:4
# =====
# username:Nicole PENG
# time:2 個月前
# comment:燈光美！舞台氣氛很好！
# rate:4
# =====
# username:Eris Feng
# time:1 年前
# comment:店內空間不大，大約有40個座位，設備舊舊的，環境不算好，位置也安排的很緊湊，飲料和食物的CP值也不高。所以來這裡的重點還是：聽，音，樂，啦！！這裡定期都會舉辦很多現場的音樂表演活動，通常都是比較還不知名的獨立歌手，場地小小的剛好有機會可以和喜歡的樂團成員靠的很近，是一個愛音樂的人會愛的地方！（不太愛看現場表演的朋友千萬別來，畢竟這裡的飲料食物價位還是咖啡廳價位...）
# rate:4
# =====

# %%
county = input()
place = input()
url = 'https://ifoodie.tw/explore/' + county + '/list/' + place + '?page='

attr = {'class': 'jsx-2133253768 title-text'}

print(url)
# Out:
# 彰化縣
# 大村鄉
# https://ifoodie.tw/explore/彰化縣/list/大村鄉

# %%
import requests
from bs4 import BeautifulSoup

county = input('輸入縣市：')
place = input('輸入地區：')
cat = input('想找的食物分類：')
url_ori = 'https://ifoodie.tw/explore/' + county + '/list/' + place + cat + '?page='

r = requests.get(url_ori)
soup = BeautifulSoup(r.text, 'html.parser')
attr_num = {'class': 'jsx-2606512903'}
temp_num = soup.find_all('span', attrs = attr_num)[2].get_text()

temp_num = temp_num.replace('(', '')
temp_num = temp_num.replace(')', '')
num = (int(temp_num)//15)+1

all_data = []
for a in range(num):
    url = url_ori + str(a+1)
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')
    attr_name = {'class': 'jsx-2133253768 title-text'}
    names = soup.find_all('a', attrs = attr_name)
    attr_rate = {'class': 'jsx-1207467136 text'}
    rate = soup.find_all('div', attrs = attr_rate)
    attr_add = {'class': 'jsx-2133253768 address-row'}
    add = soup.find_all('div', attrs = attr_add)
    for i, j, l in zip(names, rate, add):
        clean_name = i.get_text()
        clean_rate = j.get_text()
        clean_add = l.get_text()
        all_data.append([clean_name, clean_rate, clean_add])

all_data = sorted(all_data, key = lambda x:x[1], reverse = True)
for b in all_data:
    print('店名：' + b[0])
    print('評價：' + b[1])
    print('地址：' + b[2])
    print('=====')
# Out:
# 輸入縣市：台北市
# 輸入地區：公館捷運站
# 想找的食物分類：
# 店名：辛殿麻辣鍋 公館店
# 評價：5.0
# 地址：台北市中正區羅斯福路三段316巷9弄1號
# =====
# 店名：東雛菊-風味鍋物
# 評價：4.9
# 地址：臺北市中正區汀州路三段127號
# =====
# 店名：冰斗喫甜
# 評價：4.9
# 地址：臺北市中正區詔安街38巷2弄5號
# =====
# 店名：水源市場甘蔗汁
# 評價：4.8
# 地址：臺北市文山區羅斯福路四段九十二號
# =====
# 店名：OnlyToast偷吃吐司專賣店
# 評價：4.8
# 地址：臺北市中正區中華路二段303巷1號
# =====
# 店名：朝鑫壽司 (朝日壽司)
# 評價：4.8
# 地址：臺北市中正區羅斯福路三段84巷2號
# =====
# 店名：法點法食 FA DEN FA SAï
# 評價：4.7
# 地址：臺北市中正區汀州路三段210號
# =====
# 店名：人性甜點
# 評價：4.7
# 地址：臺北市中正區羅斯福路三段286巷4弄1號
# =====
# 店名：The Misanthrope Society 厭世會社
# 評價：4.7
# 地址：臺北市中正區羅斯福路四段40巷1之2號
# =====
# 店名：聾啞雞蛋糕
# 評價：4.7
# 地址：臺北市大安區汀州路三段253號
# =====
# 店名：彼克蕾友善咖啡館
# 評價：4.7
# 地址：臺北市大安區新生南路三段76巷5號
# =====
# 店名：狗一下居食酒屋 忠孝店
# 評價：4.7
# 地址：臺北市大安區敦化南路一段190巷18號
# =====
# 店名：小原田 公館店
# 評價：4.6
# 地址：臺北市大安區羅斯福路三段277號2F
# =====
# 店名：Mr.雪腐 公館店
# 評價：4.6
# 地址：臺北市中正區羅斯福路三段244巷21號
# =====
# 店名：I.C. Airport 冰淇淋機場
# 評價：4.6
# 地址：臺北市大安區溫州街74巷8號
# =====
# 店名：Jana cafe 嚼咖啡餐廳
# 評價：4.6
# 地址：台北市大安區泰順街60巷27號1樓
# =====
# 店名：聞山咖啡 臺大店
# 評價：4.6
# 地址：臺北市大安區新生南路三段56巷11之1號
# =====
# 店名：黃家香腸
# 評價：4.6
# 地址：臺北市中正區泉州街32之3號
# =====
# 店名：真劍拉麵
# 評價：4.6
# 地址：臺北市大安區師大路126巷1號
# =====
# 店名：樂野食
# 評價：4.6
# 地址：臺北市大安區忠孝東路三段217巷2弄16號
# =====
# 店名：地中海牛排館 歐華酒店
# 評價：4.6
# 地址：臺北市中山區林森北路646號
# =====
# 店名：Elfin Restaurant & Lounge
# 評價：4.6
# 地址：臺北市大安區復興南路一段107巷5弄21號
# =====
# 店名：iCookie私房手作
# 評價：4.6
# 地址：臺北市大安區杭州南路二段89號
# =====
# 店名：咕咕咕嚕昆布火鍋 大安店
# 評價：4.6
# 地址：臺北市大安區大安路一段19巷6號
# =====
# 店名：稻咖哩
# 評價：4.5
# 地址：臺北市大安區溫州街79號
# =====
# 店名：89 LOOP Sports Bar
# 評價：4.5
# 地址：臺北市中正區羅斯福路四段134號2樓號
# =====
# 店名：韓庭州
# 評價：4.5
# 地址：臺北市大安區溫州街87號
# =====
# 店名：三時午咖哩屋
# 評價：4.5
# 地址：臺北市中正區羅斯福路四段92號1樓
# =====
# 店名：赤神日式豬排
# 評價：4.5
# 地址：臺北市中正區羅斯福路3段286巷4弄14號
# =====
# 店名：靜壽司
# 評價：4.5
# 地址：臺北市中正區羅斯福路三段316巷7之1號
# =====
# 店名：鼎豐鴛鴦麻辣火鍋
# 評價：4.5
# 地址：臺北市文山區羅斯福路四段200號
# =====
# 店名：Pica Pica Café 喜鵲咖啡
# 評價：4.5
# 地址：臺北市大安區羅斯福路三段269巷74號
# =====
# 店名：coco Brownies
# 評價：4.5
# 地址：台北市大安區羅斯福路三段283巷14弄16-1號
# =====
# 店名：米米珈琲 MiMi's Cafe
# 評價：4.5
# 地址：臺北市中正區羅斯福路三段284巷15號
# =====
# 店名：Pizza Guild 比薩幫
# 評價：4.5
# 地址：臺北市大安區新生南路三段102號1樓
# =====
# 店名：山嵐拉麵公館店
# 評價：4.5
# 地址：臺北市中正區羅斯福路四段136巷1弄13號
# =====
# 店名：雞排本色 台北公館店
# 評價：4.5
# 地址：臺北市中正區羅斯福路四段24巷12弄7號
# =====
# 店名：尖蚪
# 評價：4.5
# 地址：臺北市中正區汀州路三段230巷57號
# =====
# 店名：哥德德式創意美食
# 評價：4.5
# 地址：臺北市大安區羅斯福路三段283巷11號
# =====
# 店名：挑豆院
# 評價：4.5
# 地址：台北市羅斯福路三段269巷2-1號
# =====
# 店名：直火人 直火燒肉丼飯屋
# 評價：4.5
# 地址：臺北市士林區大北路7號
# =====
# 店名：Flügel Studio
# 評價：4.5
# 地址：臺北市大安區辛亥路一段34巷3號
# =====
# 店名：GUMGUM Beer & Wings 雞翅啤酒吧
# 評價：4.5
# 地址：臺北市信義區光復南路473巷11弄38號
# =====
# 店名：栢麗廳 (晶華酒店)
# 評價：4.5
# 地址：臺北市中山區中山北路二段41號
# =====
# 店名：江雁塘新時尚鐵板燒
# 評價：4.5
# 地址：臺北市新生北路三段7號1樓
# =====
# 店名：Mirage Bistro & Cafe @荒漠甘泉
# 評價：4.4
# 地址：臺北市中正區羅斯福路三段316巷18號
# =====
# 店名：Shishlik Pita x Kebab 西西里克中東串燒（餐館店）
# 評價：4.4
# 地址：臺北市中正區羅斯福路四段138號2樓
# =====
# 店名：小日子商號
# 評價：4.4
# 地址：台北市羅斯福路四段52巷16弄13號
# =====
# 店名：威宇牛排-公館店
# 評價：4.4
# 地址：臺北市中正區汀州路三段257號
# =====
# 店名：YumYum 好吃好吃2號店
# 評價：4.4
# 地址：臺北市中正區羅斯福路三段316巷16號2樓
# =====
# 店名：picnic野餐咖啡
# 評價：4.4
# 地址：臺北市大安區溫州街75號
# =====
# 店名：成真咖啡 台北台大店
# 評價：4.4
# 地址：臺北市大安區新生南路三段110號
# =====
# 店名：吃吐吧
# 評價：4.4
# 地址：臺北市中正區羅斯福路四段78巷1弄1號
# =====
# 店名：感恩小館
# 評價：4.4
# 地址：臺北市大安區新生南路三段56巷6號
# =====
# 店名：貳樓餐廳Second Floor Cafe 敦南店
# 評價：4.4
# 地址：臺北市大安區敦化南路二段63巷14號
# =====
# 店名：3隻貓頭鷹文創
# 評價：4.4
# 地址：臺北市大安區和平東路二段96巷15弄38號
# =====
# 店名：平安京茶事
# 評價：4.4
# 地址：臺北市中正區師大路165號
# =====
# 店名：公寓咖啡館 AGCT apartment
# 評價：4.4
# 地址：臺北市大安區溫州街49巷2之2號
# =====
# 店名：小路咖啡 dear Deer
# 評價：4.4
# 地址：臺北市大安區羅斯福路二段77巷7號
# =====
# 店名：陳季炸雞 北投店
# 評價：4.4
# 地址：臺北市北投區公舘路5號
# =====
# 店名：温州街蘿蔔絲餅達人
# 評價：4.4
# 地址：臺北市大安區和平東路一段186之1號
# =====
# 店名：爐子煮賣所 Forno & Stufa
# 評價：4.4
# 地址：臺北市文山區汀州路四段132號
# =====
# 店名：小日子商号 永康店
# 評價：4.4
# 地址：臺北市大安區永康街51之1號
# =====
# 店名：龜記茗品-南西店
# 評價：4.4
# 地址：臺北市大同區南京西路18巷6之2號1樓
# =====
# 店名：三角冰
# 評價：4.4
# 地址：臺北市文山區羅斯福路五段170巷10號
# =====
# 店名：龍涎居雞膳食坊
# 評價：4.4
# 地址：臺北市大安區羅斯福路三段135號
# =====
# 店名：糊塗麵
# 評價：4.4
# 地址：臺北市大安區溫州街22巷11號
# =====
# 店名：雪可屋
# 評價：4.4
# 地址：臺北市大安區溫州街86號
# =====
# 店名：半路咖啡
# 評價：4.4
# 地址：臺北市大安區羅斯福路三段269巷51弄9號
# =====
# 店名：中央公園咖啡館
# 評價：4.4
# 地址：臺北市中正區羅斯福路三段240巷3號
# =====
# 店名：Waiting Bistro
# 評價：4.4
# 地址：台北市大安區忠孝東路三段251巷13弄6號1樓
# =====
# 店名：好米亞 Goodies Cuisine
# 評價：4.4
# 地址：臺北市大安區敦化南路一段270巷6號
# =====
# 店名：瓦法奇朵
# 評價：4.4
# 地址：臺北市中正區信陽街29號
# =====
# 店名：Hi-Q褐藻生活館x鱻食
# 評價：4.4
# 地址：臺北市松山區八德路四段123之1號1樓
# =====
# 店名：BFF Gossip Brunch 早午餐
# 評價：4.3
# 地址：臺北市中正區羅斯福路三段244巷14號
# =====
# 店名：戰醬燒肉
# 評價：4.3
# 地址：臺北市中正區羅斯福路三段316巷7之3號
# =====
# 店名：鱷吐司 A Toast
# 評價：4.3
# 地址：台北市中正區羅斯福路三段316巷8弄7號
# =====
# 店名：Happy fatty幸福肥
# 評價：4.3
# 地址：臺北市中正區汀州路三段91號1樓
# =====
# 店名：幸好沒錯過你 Master K.
# 評價：4.3
# 地址：臺北市中正區羅斯福路四段78巷1弄5號
# =====
# 店名：極麵屋-豚骨/公館拉麵/丼飯
# 評價：4.3
# 地址：臺北市中正區羅斯福路四段136巷6弄2號
# =====
# 店名：指有雞飯 CHICKEN RICE ONLY
# 評價：4.3
# 地址：臺北市大安區溫州街74巷五弄3號
# =====
# 店名：曉鹿鳴樓
# 評價：4.3
# 地址：臺北市大安區羅斯福路四段85號
# =====
# 店名：El Sabroso Mexican Food
# 評價：4.3
# 地址：臺北市中正區汀州路三段107號之一
# =====
# 店名：狗一下居食酒屋公館店
# 評價：4.3
# 地址：臺北市中正區汀州路三段271號
# =====
# 店名：Pasta 2 Go
# 評價：4.3
# 地址：台北市大安區新生南路三段72號
# =====
# 店名：池先生咖哩屋
# 評價：4.3
# 地址：臺北市大安區復興南路二段385號
# =====
# 店名：同安街麵線羹
# 評價：4.3
# 地址：臺北市中正區同安街85之1號
# =====
# 店名：小仺館 Cafe & Rice
# 評價：4.3
# 地址：臺北市大安區羅斯福路三段77號
# =====
# 店名：肉多多火鍋-古亭旗艦店
# 評價：4.3
# 地址：臺北市大安區羅斯福路二段79號3樓
# =====
# 店名：青田七六
# 評價：4.3
# 地址：臺北市大安區青田街七巷六號
# =====
# 店名：宣德炭燒羊肉爐
# 評價：4.3
# 地址：臺北市文山區景隆街40號
# =====
# 店名：站食可以
# 評價：4.3
# 地址：臺北市中正區羅斯福路四段24巷12弄7號
# =====
# 店名：師園鹽酥雞
# 評價：4.3
# 地址：臺北市大安區師大路39巷14號
# =====
# 店名：龍泉深海鮮魚湯
# 評價：4.3
# 地址：臺北市大安區師大路117巷7號
# =====
# 店名：雙月食品社 青島店
# 評價：4.3
# 地址：臺北市中正區青島東路6之2號
# =====
# 店名：Paul 仁愛店
# 評價：4.3
# 地址：臺北市大安區仁愛路四段107號1F
# =====
# 店名：Bravo Burger 發福廚房 (台大店)
# 評價：4.3
# 地址：台北市中正區羅斯福路四段44之1號2樓
# =====
# 店名：川賀燒烤居酒屋
# 評價：4.3
# 地址：臺北市中山區合江街92號
# =====
# 店名：Cafe Bastille
# 評價：4.2
# 地址：臺北市大安區溫州街91號
# =====
# 店名：泰正點
# 評價：4.2
# 地址：臺北市中正區汀州路三段166號
# =====
# 店名：Chic Thai 泰式新定食
# 評價：4.2
# 地址：臺北市中正區汀州路三段166號2樓
# =====
# 店名：找到咖啡
# 評價：4.2
# 地址：臺北市大安區羅斯福路四段1號
# =====
# 店名：片場咖啡
# 評價：4.2
# 地址：臺北市大安區新生南路三段70巷6號
# =====
# 店名：chef's cafe waffle 瓦福
# 評價：4.2
# 地址：臺北市大安區羅斯福路四段12巷1號
# =====
# 店名：丼壽司
# 評價：4.2
# 地址：臺北市中正區汀州路三段165號一樓
# =====
# 店名：墨洋拉麵
# 評價：4.2
# 地址：臺北市中正區羅斯福路四段136巷10號
# =====
# 店名：初牛 公館店
# 評價：4.2
# 地址：台北市汀州路3段169號
# =====
# 店名：鳳城燒臘粵菜
# 評價：4.2
# 地址：臺北市大安區新生南路三段58之3號
# =====
# 店名：好想吃冰 かき氷
# 評價：4.2
# 地址：臺北市大安區溫州街80號
# =====
# 店名：埃及口味沙威瑪
# 評價：4.2
# 地址：台北市大安區羅斯福路三段325號
# =====
# 店名：珍記豬血糕
# 評價：4.2
# 地址：臺北市中正區汀州路三段187號
# =====
# 店名：劉記古早味蔥蛋餅
# 評價：4.2
# 地址：臺北市中正區羅斯福路四段108巷2之3號
# =====
# 店名：蘇活義大利麵坊
# 評價：4.2
# 地址：臺北市大安區新生南路三段60巷3號
# =====
# 店名：霞飛驛PoSt義大利麵
# 評價：4.2
# 地址：臺北市大安區新生南路三段60巷8號
# =====
# 店名：自來水園區
# 評價：4.2
# 地址：臺北市中正區思源街1號
# =====
# 店名：希斯酪義大利麵
# 評價：4.2
# 地址：臺北市北投區公館路420號
# =====
# 店名：偵軒廚房
# 評價：4.2
# 地址：臺北市文山區羅斯福路六段28號
# =====
# 店名：三米三小館
# 評價：4.2
# 地址：臺北市中正區羅斯福路三段286巷4弄12號
# =====
# 店名：何太守港式菠蘿包專賣店
# 評價：4.2
# 地址：臺北市中正區汀州路三段167號
# =====
# 店名：胡饕米粉湯•黑白切 台大公館店
# 評價：4.2
# 地址：臺北市中正區羅斯福路三段284巷8號1樓
# =====
# 店名：路上撿到一隻貓
# 評價：4.2
# 地址：臺北市大安區溫州街49巷2號
# =====
# 店名：Oyami Cafe
# 評價：4.2
# 地址：臺北市萬華區武昌街二段50巷15號2樓
# =====
# 店名：スシロー壽司郎 台北公館店
# 評價：4.2
# 地址：臺北市中正區羅斯福路四段68號2樓
# =====
# 店名：O Steak 歐牛排 法式餐酒館
# 評價：4.2
# 地址：台北市大安區金華街164巷1弄6號
# =====
# 店名：窩巷弄
# 評價：4.1
# 地址：臺北市中正區羅斯福路四段78巷1弄11號
# =====
# 店名：好處 Have A Nice Day
# 評價：4.1
# 地址：大安區羅斯福路三段283巷14弄30號
# =====
# 店名：竹の丼飯屋
# 評價：4.1
# 地址：臺北市中正區羅斯福路四段92號
# =====
# 店名：賢夫美食
# 評價：4.1
# 地址：臺北市中正區羅斯福路四段92號79攤
# =====
# 店名：龍潭豆花
# 評價：4.1
# 地址：臺北市中正區汀州路三段239號
# =====
# 店名：兄弟蚵仔麵線
# 評價：4.1
# 地址：臺北市中正區汀州路三段235號
# =====
# 店名：香港泉記小吃館
# 評價：4.1
# 地址：臺北市中正區羅斯福路四段24巷12弄3號
# =====
# 店名：小木屋鬆餅
# 評價：4.1
# 地址：臺北市大安區羅斯福路四段1號
# =====
# 店名：鷹流拉麵極匠
# 評價：4.1
# 地址：臺北市中正區汀州路三段104巷4號
# =====
# 店名：公館酒釀湯圓
# 評價：4.1
# 地址：臺北市中正區羅斯福路四段14號
# =====
# 店名：晴光紅豆餅 (公館店)
# 評價：4.1
# 地址：台北市中正區汀洲路三段255號
# =====
# 店名：Kitchen66
# 評價：4.1
# 地址：臺北市大安區溫州街74巷3弄11號
# =====
# 店名：麻油雞
# 評價：4.1
# 地址：臺北市大安區公館夜市商圈
# =====
# 店名：巴和奈野 illy Cafe（奈野咖啡二店）
# 評價：4.1
# 地址：臺北市中正區羅斯福路二段81巷16弄5號
# =====
# 店名：すき家sukiya
# 評價：4.1
# 地址：臺北市中正區羅斯福路二段50號
# =====
# 店名：素食地瓜球
# 評價：4.1
# 地址：臺北市中正區羅斯福路四段108巷8之1號
# =====
# 店名：凰上您好-台北-公館店 Dear Queen Tea
# 評價：4.1
# 地址：臺北市中正區汀州路三段174之1號
# =====
# 店名：林伯蘿蔔糕
# 評價：4.1
# 地址：台北市中正區羅斯福路二段164-1號
# =====
# 店名：貳樓餐廳師大店
# 評價：4.1
# 地址：臺北市大安區師大路24號
# =====
# 店名：母女の店泰式簡餐
# 評價：4.1
# 地址：臺北市中正區羅斯福路三段286巷4弄10號
# =====
# 店名：光一肆號
# 評價：4.1
# 地址：臺北市大安區新生南路三段76巷2號
# =====
# 店名：首都烘焙餐廳-公館店
# 評價：4.1
# 地址：臺北市中正區羅斯福路三段284巷12號1樓
# =====
# 店名：鄰居家NEXT DOOR
# 評價：4.1
# 地址：臺北市大安區永康街2巷9號
# =====
# 店名：翠薪越南餐廳
# 評價：4.0
# 地址：臺北市中正區羅斯福路四段24巷11號
# =====
# 店名：B.R Junior
# 評價：4.0
# 地址：臺北市中正區羅斯福路四段52巷6號1樓
# =====
# 店名：大盛豬排專門店
# 評價：4.0
# 地址：臺北市中正區羅斯福路四段52巷16弄15之1號
# =====
# 店名：台一牛奶大王
# 評價：4.0
# 地址：臺北市大安區新生南路三段82號
# =====
# 店名：ImPerfect Café
# 評價：4.0
# 地址：臺北市大安區新生南路三段96之5號二樓
# =====
# 店名：祥記號美食小吃
# 評價：4.0
# 地址：臺北市中正區羅斯福路四段92號
# =====
# 店名：泰國小館
# 評價：4.0
# 地址：臺北市中正區汀州路三段219號
# =====
# 店名：牛洞食堂
# 評價：4.0
# 地址：臺北市大安區羅斯福路三段277號羅斯福大廈
# =====
# 店名：台電勵進餐廳
# 評價：4.0
# 地址：臺北市大安區和平東路一段55巷5號
# =====
# 店名：加里曼丹印尼美食
# 評價：4.0
# 地址：臺北市中正區金門街1號
# =====
# 店名：鍋in百元風味火鍋
# 評價：4.0
# 地址：臺北市中正區汀州路三段196號
# =====
# 店名：義饗食堂
# 評價：3.9
# 地址：臺北市中正區羅斯福路四段83號2樓
# =====
# 店名：ToasToast 土司吐司
# 評價：3.9
# 地址：臺北市中正區汀州路三段160巷4之3號
# =====
# 店名：池先生 Kopitiam 公館店
# 評價：3.9
# 地址：臺北市中正區羅斯福路三段284巷10號
# =====
# 店名：首爾之家
# 評價：3.9
# 地址：臺北市中正區羅斯福路三段244巷10弄14號
# =====
# 店名：維綸麵食館
# 評價：3.9
# 地址：臺北市中正區汀州路三段279號
# =====
# 店名：ville cafe
# 評價：3.9
# 地址：臺北市中正區羅斯福路三段284巷5號
# =====
# 店名：瓦崎燒烤火鍋 敦南店
# 評價：3.9
# 地址：臺北市大安區敦化南路一段160巷60號
# =====
# 店名：珍煮丹
# 評價：3.9
# 地址：臺北市士林區大南路132號
# =====
# 店名：THAIHAND 右手餐廳
# 評價：3.8
# 地址：臺北市中正區羅斯福路三段306號
# =====
# 店名：Lacuz 新泰食餐廳
# 評價：3.8
# 地址：臺北市中正區羅斯福路四段85號2樓
# =====
# 店名：小李豬血糕
# 評價：3.8
# 地址：臺北市中正區羅斯福路四段136巷1之3號
# =====
# 店名：黛黛茶 DailyDae公館秀泰店-歐風水果茶
# 評價：3.8
# 地址：臺北市中正區羅斯福路四段136巷3號
# =====
# 店名：瓦崎燒烤火鍋 公館店
# 評價：3.8
# 地址：臺北市中正區羅斯福路四段24巷5號
# =====
# 店名：藍家割包
# 評價：3.8
# 地址：臺北市中正區羅斯福路三段316巷8弄3號
# =====
# 店名：Mr. 拉麵野崎家
# 評價：3.8
# 地址：臺北市中正區羅斯福路三段316巷9弄2號
# =====
# 店名：十二巷拉麵
# 評價：3.8
# 地址：臺北市中正區羅斯福路四段12巷1號
# =====
# 店名：至香園小吃店
# 評價：3.8
# 地址：臺北市大安區新生南路三段86巷15號
# =====
# 店名：金牛座牛排館
# 評價：3.8
# 地址：臺北市中正區羅斯福路三段316巷8弄8號
# =====
# 店名：Mr.拉麵公館店
# 評價：3.8
# 地址：臺北市中正區羅斯福路三段284巷11號
# =====
# 店名：雞二拉麵 師大店
# 評價：3.8
# 地址：臺北市大安區羅斯福路三段139號
# =====
# 店名：スシロー壽司郎 台灣旗艦店
# 評價：3.8
# 地址：臺北市中正區館前路8號2樓
# =====
# 店名：倆倆號
# 評價：3.7
# 地址：台北市中正區汀州路三段158-1號
# =====
# 店名：泰味鮮
# 評價：3.7
# 地址：臺北市中正區羅斯福路三段316巷8弄3之4號
# =====
# 店名：呷飯團
# 評價：3.7
# 地址：臺北市中正區羅斯福路四段78巷2弄2號
# =====
# 店名：金雞園
# 評價：3.7
# 地址：臺北市中正區羅斯福路三段316巷8弄3之1號
# =====
# 店名：幸福村潤餅
# 評價：3.7
# 地址：臺北市大安區羅斯福路三段316巷內
# =====
# 店名：得記蛋糕
# 評價：3.7
# 地址：臺北市中正區羅斯福路四段26號
# =====
# 店名：轟炸雞排
# 評價：3.7
# 地址：台北市中正區羅斯福路四段136巷3號1樓
# =====
# 店名：泰街頭
# 評價：3.6
# 地址：臺北市大安區溫州街74巷6號1樓
# =====
# 店名：鴉片粉圓
# 評價：3.6
# 地址：臺北市中正區羅斯福路四段52巷16弄4號
# =====
# 店名：今日壽司店
# 評價：3.6
# 地址：臺北市大安區臨江街106之2號
# =====
# 店名：得記港式麻辣鴨血
# 評價：3.5
# 地址：臺北市中正區羅斯福路四段52巷16弄4號
# =====
# 店名：小飯館兒
# 評價：3.5
# 地址：臺北市中正區汀洲路三段202號
# =====
# 店名：費斯達香草洋食館
# 評價：3.5
# 地址：臺北市中正區羅斯福路三段316巷8弄14號
# =====
# 店名：南城泰式料理
# 評價：3.5
# 地址：臺北市中正區汀州路三段171號
# =====
# 店名：Bonnie sugar
# 評價：3.5
# 地址：臺北市大安區師大路93巷8號
# =====
# 店名：阿英滷肉飯
# 評價：3.4
# 地址：臺北市大安區溫州街74巷5弄1號
# =====
# 店名：蕭家傳統小吃
# 評價：3.3
# 地址：臺北市中正區羅斯福路四段90巷6號
# =====
# 店名：劉家水煎包
# 評價：3.3
# 地址：臺北市中正區汀州路三段189號
# =====
# 店名：檀島香港茶餐廳
# 評價：3.3
# 地址：臺北市信義區松壽路11號b1號
# =====
# 店名：轉轉發現義大利麵
# 評價：3.2
# 地址：臺北市大安區新生南路三段86巷6號
# =====
# 店名：阿剛泰式主題餐廳
# 評價：2.6
# 地址：臺北市中正區汀州路三段150號
# =====
